-- %%
require 'torch'
-- Out:
-- {
--   deserialize : function: 0x41825270
--   cat : function: 0x41820ce8
--   cdata : function: 0x40d4c200
--   newmetatable : function: 0x41803a28
--   atan2 : function: 0x4058a8a0
--   random : function: 0x41820d10
--   zero : function: 0x4058a260
--   logNormal : function: 0x4058a9e0
--   sigmoid : function: 0x4058a800
--   getnumcores : function: 0x41803748
--   cross : function: 0x41820b08
--   deserializeFromStorage : function: 0x41824ac0
--   inverse : function: 0x4058ab20
--   updateerrorhandlers : function: 0x41803530
--   isTypeOf : function: 0x4058db38
--   ByteStorage : table: 0x40d48c58
--   prod : function: 0x41820a18
--   ger : function: 0x41820888
--   eq : function: 0x4058b2c8
--   getnumthreads : function: 0x418036f8
--   ByteTensor : table: 0x4181dc90
--   Timer : table: 0x4181fbc8
--   addmv : function: 0x418208b0
--   lerp : function: 0x4058a878
--   match : function: 0x4058a490
--   Allocator : table: 0x4058d558
--   xcorr2 : function: 0x41820e00
-- ...

-- %%
test = torch.Tensor(75):normal(0, 1)

-- %%
test
-- Out:
--  1.1466
-- -0.5582
-- -1.1206
--  0.0572
-- -1.3743
--  0.3793
-- -0.3504
--  0.2450
--  0.2075
--  1.2740
-- -0.9537
-- -0.5747
--  0.6395
--  0.5410
--  1.1461
--  0.9263
-- -1.2881
-- -0.1284
-- -0.2857
--  0.1576
--  1.4007
-- -0.2220
--  0.2601
-- -1.9142
--  0.4905
--  0.3461
-- -0.2873
--  0.2537
-- -1.3059
--  1.2469
--  0.7391
--  1.2702
-- -0.7642
-- -0.5514
-- -0.7140
-- -0.7508
--  2.8835
-- -0.2340
--  1.5321
--  1.1483
--  0.3211
-- -0.7385
-- -1.6325
--  2.5172
-- -0.4366
-- -0.1140
--  0.0229
--  0.9685
--  0.4083
--  0.8451
-- -0.8429
-- -1.0188
-- -0.5588
--  0.7012
-- -1.0596
-- -1.3361
-- -0.3612
--  1.6280
-- -0.3290
--  0.9698
-- -1.0183
--  0.6149
-- -0.5579
-- -0.8405
-- -0.2157
-- -0.7421
-- -0.2997
-- -0.5676
--  1.2245
--  0.7393
-- -2.0214
--  1.9211
-- -0.5512
--  0.7899
--  1.5572
-- [torch.DoubleTensor of size 75]
